# %%
car_01 = {
    "No" : "1",
    "Brand" : "Toyota",
    "Model" : "Corolla",
    "Color" : "Red"
}

# %%
car_02 = {
    "No" : "2",
    "Brand" : "Honda",
    "Model" : "Civic",
    "Color" : "Black"
}

# %%
car_information_list = [
    car_01,car_02
]

# %%
car_information_dict = [
    {
    "No" : "1",
    "Brand" : "Toyota",
    "Model" : "Corolla",
    "Color" : "Red"
},
     {
    "No" : "2",
    "Brand" : "Honda",
    "Model" : "Civic",
    "Color" : "Black"
}
]

# %%
# 딕션너어리에서 특정값 확인
# car_information_dict [1]["Model"]

# %% [markdown]
# 🟩 문제 1. 리스트 만들기
#
# 회사원 이름을 순서대로 리스트에 저장해 보세요.
# 리스트 이름: employees
#
# 번호
# 이름
# 1
# Alice
# 2
# Bob
# 3
# Charlie
# 4
# Diana
#
# employees 리스트를 만들어 보세요
# Alice 출력
# Charlie 출력

# %%
employees = ["Alice","Bob","Charile","Diana"]

# %%
print (employees[0])
# Out:
# Alice

# %% [markdown]
# 🟩 문제 2. 딕셔너리 만들기
#
# 한 명의 회사원 정보를 딕셔너리로 만들어 보세요.
#
# 딕셔너리 이름: employee1
# 키
# 값
# name
# Alice
# department
# Sales
# position
# Manager
# year
# 2023
#
# employee1 딕셔너리를 만들어 보세요
# “Manager” 를 출력

# %%
employees1 = {"name" : "Alice","department":"Sales","position":"Manager","year":"2023"}

# %%
employees1["position"]
# Out:
# 'Manager'

# %% [markdown]
# 🟩 문제 3. 리스트 안 딕셔너리 만들기
#
# 여러 회사원의 정보를 리스트 안 딕셔너리 형태로 만들어 보세요.
#  리스트 이름: all_employees
#
#  all_employees 리스트 안에 딕셔너리를 만들어 보세요
#
# name
# department
# position
# year
# Alice
# Sales
# Manager
# 2023
# Bob
# IT
# Engineer
# 2022
# Charlie
# HR
# Staff
# 2023
# Diana
# Marketing
# Analyst
# 2024
#
# 3 번째 직원 정보 출력
# 2 번째 position 출력

# %%
all_employees = [
    {"name" : "Alice","department":"Sales","position":"Manager","year":"2023"},
    {"name" : "Bob","department":"IT","position":"Engineer","year":"2022"},
    {"name" : "Charlie","department":"HR","position":"Staff","year":"2023"}

]

# %%
all_employees[2]["position"]
# Out:
# 'Staff'
